# %%
import pandas as pd 
import numpy as np

# %%
dataset=pd.read_csv('Diabties.csv')

# %%
dataset.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
dataset.shape
# Out:
# (768, 9)

# %%
dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
dataset['SkinThickness'].describe()
# Out:
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
dataset['SkinThickness']
# Out:
# 0      35
# 1      29
# 2       0
# 3      23
# 4      35
#        ..
# 763    48
# 764    27
# 765    23
# 766     0
# 767    31
# Name: SkinThickness, Length: 768, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
corr = dataset.corr()
print(corr)
sns.heatmap(corr, 
         xticklabels=corr.columns, 
         yticklabels=corr.columns)
plt.savefig('Heatmap.png', dpi=300, bbox_inches='tight')
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print('total number of rows:{0}'.format(len(dataset)))
print("number of rows missing glucose:{0}".format(len(dataset.loc[dataset['Glucose']==0])))
print("number of rows missing BloodPressure:{0}".format(len(dataset.loc[dataset['BloodPressure']==0])))
print("number of rows missing SkinThickness:{0}".format(len(dataset.loc[dataset['SkinThickness']==0])))
print("number of rows missing Insulin:{0}".format(len(dataset.loc[dataset['Insulin']==0])))
print("number of rows missing Age:{0}".format(len(dataset.loc[dataset['Age']==0])))
print("number of rows missing Pregnancies:{0}".format(len(dataset.loc[dataset['Pregnancies']==0])))
# Out:
# total number of rows:768
# number of rows missing glucose:5
# number of rows missing BloodPressure:35
# number of rows missing SkinThickness:227
# number of rows missing Insulin:374
# number of rows missing Age:0
# number of rows missing Pregnancies:111

# %%
#from sklearn.impute import SimpleImputer
#fill_values=SimpleImputer(missing_values=0,strategy='mean',verbose=2)
#dataset=fill_values.fit_transform(dataset)

# %%
diabetes_positive=len(dataset[dataset['Outcome']==1])
diabetes_negative=len(dataset[dataset['Outcome']==0])

# %%
(diabetes_positive,diabetes_negative)
# Out:
# (268, 500)

# %%
print(("Positive Percentage:{0}".format(int((diabetes_positive/dataset['Outcome'].count())*100))))
print(("Negative Percentage:{0}".format(int((diabetes_negative/dataset['Outcome'].count())*100))))
# Out:
# Positive Percentage:34
# Negative Percentage:65

# %%
feature_columns=[dataset['BloodPressure'],dataset['SkinThickness'],dataset['Age'],dataset['Glucose']]

# %% [markdown]
# Creating boxplots

# %%
import matplotlib.pyplot as plt
fig = plt.figure(1, figsize=(10,8))
ax = fig.add_subplot(111)
Ps = ax.boxplot(feature_columns)
fig.savefig('box_plot.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

bins = [20,25,30,35,40,45,50,55,60,65,70,75,80]

plt.hist(dataset['Age'], bins, histtype='bar', rwidth=0.5)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('No of Persons')
fig.savefig('Age Distribution')
plt.savefig('Age_Distribution_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
split_age1=dataset[dataset['Age']<30]
split_age2=dataset[dataset['Age']>30]
Insulin_group1=int(split_age1['Insulin'].mean())
Insulin_group2=int(split_age2['Insulin'].mean())
print(Insulin_group1,Insulin_group2)
# Out:
# 84 74

# %%
dataset['Insulin']=dataset['Insulin'].replace(0,int(dataset['Insulin'].mean()))
dataset['SkinThickness']=dataset['SkinThickness'].replace(0,int(dataset['SkinThickness'].mean()))
#dataset['Pregnancies']=dataset['Pregnancies'].replace(0,int(dataset['Pregnancies'].mean()))

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35       79  33.6
# 1            1       85             66             29       79  26.6
# 2            8      183             64             20       79  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.model_selection import train_test_split
features_columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
predicted_class=['Outcome']
x=dataset[features_columns].values
y=dataset[predicted_class].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
print(x_train.shape,y_test.shape)
# Out:
# (614, 8) (154, 1)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=500)
model.fit(x_train,y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8246753246753247

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[98  9]
#  [18 29]]

# %%
#normalisation and Roc curve for thershold value
#hyperparameter tuning

# %%
from sklearn.metrics import roc_curve
from numpy import sqrt
from numpy import argmax
from matplotlib import pyplot
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
#pyplot.scatter(0.5,0.78, marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# save the plot
plt.savefig('Threshold_plot.png', dpi=300, bbox_inches='tight')
pyplot.show()

# %%
from sklearn.metrics import precision_recall_curve
testy=y_test
yhat=y_pred
# calculate pr-curve
precision, recall, thresholds = precision_recall_curve(y_test,y_pred)
# plot the roc curve for the model
no_skill = len(testy[testy==1]) / len(testy)
pyplot.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
pyplot.plot(recall, precision, marker='.', label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
pyplot.legend()
#save the plot
plt.savefig('Recall_Precision_plot.png', dpi=300, bbox_inches='tight')
# show the plot
pyplot.show()

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, roc_auc_score, precision_score
clf = LogisticRegression(class_weight="balanced",max_iter=500)
clf.fit(x_train, y_train.ravel())
THRESHOLD = 0.65
preds = np.where(clf.predict_proba(x_test)[:,1] > THRESHOLD, 1, 0)

pd.DataFrame(data=[accuracy_score(y_test, preds), recall_score(y_test, preds),
                   precision_score(y_test, preds), roc_auc_score(y_test, preds)], 
             index=["accuracy", "recall", "precision", "roc_auc_score"])
# Out:
#                       0
# accuracy       0.824675
# recall         0.617021
# precision      0.763158
# roc_auc_score  0.766455

# %%
model.get_params(deep=True)
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 500,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.predict_proba(x_test)
# Out:
# array([[0.04690728, 0.95309272],
#        [0.83234904, 0.16765096],
#        [0.90215488, 0.09784512],
#        [0.35952022, 0.64047978],
#        [0.87678979, 0.12321021],
#        [0.96041052, 0.03958948],
#        [0.25686432, 0.74313568],
#        [0.15128078, 0.84871922],
#        [0.61493859, 0.38506141],
#        [0.62237984, 0.37762016],
#        [0.42926337, 0.57073663],
#        [0.03941495, 0.96058505],
#        [0.71180159, 0.28819841],
#        [0.82519878, 0.17480122],
#        [0.88269613, 0.11730387],
#        [0.8505676 , 0.1494324 ],
#        [0.14141763, 0.85858237],
#        [0.97427454, 0.02572546],
#        [0.59824843, 0.40175157],
#        [0.74205069, 0.25794931],
#        [0.35843796, 0.64156204],
#        [0.57021027, 0.42978973],
#        [0.79466002, 0.20533998],
#        [0.93867523, 0.06132477],
#        [0.94685663, 0.05314337],
#        [0.6603688 , 0.3396312 ],
#        [0.95440705, 0.04559295],
#        [0.09178952, 0.90821048],
#        [0.89509305, 0.10490695],
#        [0.85405324, 0.14594676],
#        [0.53547667, 0.46452333],
#        [0.75133582, 0.24866418],
#        [0.90137826, 0.09862174],
#        [0.54733793, 0.45266207],
#        [0.89524176, 0.10475824],
#        [0.28101968, 0.71898032],
#        [0.54309929, 0.45690071],
#        [0.911369  , 0.088631  ],
#        [0.6698086 , 0.3301914 ],
#        [0.25315569, 0.74684431],
#        [0.70853073, 0.29146927],
#        [0.77314688, 0.22685312],
#        [0.83504477, 0.16495523],
#        [0.18658968, 0.81341032],
#        [0.25327714, 0.74672286],
#        [0.99234361, 0.00765639],
#        [0.91415334, 0.08584666],
#        [0.79458958, 0.20541042],
#        [0.65067992, 0.34932008],
#        [0.69383231, 0.30616769],
#        [0.5902616 , 0.4097384 ],
#        [0.80610814, 0.19389186],
#        [0.12343091, 0.87656909],
#        [0.53480677, 0.46519323],
#        [0.85637818, 0.14362182],
#        [0.99739165, 0.00260835],
#        [0.94306407, 0.05693593],
#        [0.42579561, 0.57420439],
#        [0.72057831, 0.27942169],
#        [0.9296997 , 0.0703003 ],
#        [0.27547984, 0.72452016],
#        [0.52013122, 0.47986878],
#        [0.8900832 , 0.1099168 ],
#        [0.27807843, 0.72192157],
#        [0.30950279, 0.69049721],
#        [0.09674951, 0.90325049],
#        [0.27725457, 0.72274543],
#        [0.85572552, 0.14427448],
#        [0.63211402, 0.36788598],
#        [0.89495005, 0.10504995],
#        [0.87166752, 0.12833248],
#        [0.59162884, 0.40837116],
#        [0.90686848, 0.09313152],
#        [0.04809625, 0.95190375],
#        [0.1452646 , 0.8547354 ],
#        [0.67618936, 0.32381064],
#        [0.87985998, 0.12014002],
#        [0.37381244, 0.62618756],
#        [0.93138069, 0.06861931],
#        [0.82324329, 0.17675671],
#        [0.65392069, 0.34607931],
#        [0.61285171, 0.38714829],
#        [0.78992419, 0.21007581],
#        [0.96754243, 0.03245757],
#        [0.8082396 , 0.1917604 ],
#        [0.77491908, 0.22508092],
#        [0.71141495, 0.28858505],
#        [0.5779423 , 0.4220577 ],
#        [0.12042853, 0.87957147],
#        [0.8008444 , 0.1991556 ],
#        [0.8470868 , 0.1529132 ],
#        [0.81888435, 0.18111565],
#        [0.76020423, 0.23979577],
#        [0.95851138, 0.04148862],
#        [0.35668014, 0.64331986],
#        [0.81144634, 0.18855366],
#        [0.56948428, 0.43051572],
#        [0.47521588, 0.52478412],
#        [0.39827657, 0.60172343],
#        [0.74942471, 0.25057529],
#        [0.7331714 , 0.2668286 ],
#        [0.90491178, 0.09508822],
#        [0.7725572 , 0.2274428 ],
#        [0.96127118, 0.03872882],
#        [0.39349521, 0.60650479],
#        [0.64306532, 0.35693468],
#        [0.86367593, 0.13632407],
#        [0.71790284, 0.28209716],
#        [0.95615006, 0.04384994],
#        [0.24816023, 0.75183977],
#        [0.89320531, 0.10679469],
#        [0.68688227, 0.31311773],
#        [0.37134649, 0.62865351],
#        [0.60998411, 0.39001589],
#        [0.45839457, 0.54160543],
#        [0.37361891, 0.62638109],
#        [0.88472641, 0.11527359],
#        [0.33650144, 0.66349856],
#        [0.90355467, 0.09644533],
#        [0.24603834, 0.75396166],
#        [0.64009134, 0.35990866],
#        [0.64773449, 0.35226551],
#        [0.70464844, 0.29535156],
#        [0.55744785, 0.44255215],
#        [0.78212567, 0.21787433],
#        [0.95303713, 0.04696287],
#        [0.66793399, 0.33206601],
#        [0.66162043, 0.33837957],
#        [0.52160097, 0.47839903],
#        [0.63339836, 0.36660164],
#        [0.63261269, 0.36738731],
#        [0.96366637, 0.03633363],
#        [0.94545293, 0.05454707],
#        [0.24213647, 0.75786353],
#        [0.69483053, 0.30516947],
#        [0.62349583, 0.37650417],
#        [0.86987526, 0.13012474],
#        [0.63079852, 0.36920148],
#        [0.33877218, 0.66122782],
#        [0.79883825, 0.20116175],
#        [0.90511117, 0.09488883],
#        [0.45747641, 0.54252359],
#        [0.92996015, 0.07003985],
#        [0.91910974, 0.08089026],
#        [0.64555283, 0.35444717],
#        [0.91783057, 0.08216943],
#        [0.92479603, 0.07520397],
#        [0.91511182, 0.08488818],
#        [0.8782806 , 0.1217194 ],
#        [0.81104956, 0.18895044],
#        [0.91603279, 0.08396721],
#        [0.33096954, 0.66903046],
#        [0.89216117, 0.10783883],
#        [0.82361626, 0.17638374]])

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'gini', random_state = 0,min_impurity_split=0.250,min_samples_split=5,ccp_alpha=0.0)
classifier.fit(x_train,y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\tree\_classes.py:301: FutureWarning: The min_impurity_split parameter is deprecated. Its default value will change from 1e-7 to 0 in version 0.23, and it will be removed in 0.25. Use the min_impurity_decrease parameter instead.
#   FutureWarning)
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=0.25,
#                        min_samples_leaf=1, min_samples_split=5,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
y_pred_dt=classifier.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_dt))
# Out:
# 0.8051948051948052

# %%
cm_dt = confusion_matrix(y_test, y_pred_dt)
print(cm_dt)
# Out:
# [[92 15]
#  [15 32]]

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = model, X = x_train,y = y_train.ravel(), cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
accuracies
# Out:
# Accuracy: 75.40 %
# Standard Deviation: 5.01 %
# array([0.72580645, 0.74193548, 0.83870968, 0.75806452, 0.70491803,
#        0.7704918 , 0.75409836, 0.6557377 , 0.81967213, 0.7704918 ])

# %%
for x in np.linspace(start=0,stop=1,num=10):
    print(x)
# Out:
# 0.0
# 0.1111111111111111
# 0.2222222222222222
# 0.3333333333333333
# 0.4444444444444444
# 0.5555555555555556
# 0.6666666666666666
# 0.7777777777777777
# 0.8888888888888888
# 1.0

# %%
from sklearn.model_selection import RandomizedSearchCV
max_iter=[100,200,300,400,500,600]
solver=['newton-cg','lbfgs','liblinear','sag','saga']
penalty=['l1','l2','elasticnet','none']
fit_intercept=['True','False']
C=[x for x in np.linspace(0.5,4.0,8)]
l1_ratio=[float(x)for x in np.linspace(start=0,stop=1,num=10)]

# %%
from sklearn.model_selection import RandomizedSearchCV

random_grid={'penalty':penalty,
             'C':C,
             'max_iter':max_iter,
             'solver':solver,
             'fit_intercept':fit_intercept,
              'l1_ratio':l1_ratio}
print(random_grid)
# Out:
# {'penalty': ['l1', 'l2', 'elasticnet', 'none'], 'C': [0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0], 'max_iter': [100, 200, 300, 400, 500, 600], 'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 'fit_intercept': ['True', 'False'], 'l1_ratio': [0.0, 0.1111111111111111, 0.2222222222222222, 0.3333333333333333, 0.4444444444444444, 0.5555555555555556, 0.6666666666666666, 0.7777777777777777, 0.8888888888888888, 1.0]}

# %%
lr=LogisticRegression()
lr_random=RandomizedSearchCV(estimator=lr,param_distributions=random_grid,n_iter=10,cv=5,verbose=2,random_state=100,n_jobs=1)

# %%
lr_random.fit(x_train,y_train.ravel())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5
# [CV]  solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5
# [CV]  solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5
# [CV]  solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5
# [CV]  solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5
# [CV]  solver=newton-cg, penalty=l1, max_iter=100, l1_ratio=0.7777777777777777, fit_intercept=True, C=1.5, total=   0.0s
# [CV] solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0
# [CV]  solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0
# [CV]  solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0
# [CV]  solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0
# [CV]  solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0
# [CV]  solver=liblinear, penalty=l2, max_iter=600, l1_ratio=0.7777777777777777, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0
# [CV]  solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0
# [CV]  solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0
# [CV]  solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0
# [CV]  solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0
# [CV]  solver=saga, penalty=none, max_iter=600, l1_ratio=0.0, fit_intercept=True, C=3.0, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5
# [CV]  solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5
# [CV]  solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5
# [CV]  solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5
# [CV]  solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5, total=   0.0s
# [CV] solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5
# [CV]  solver=saga, penalty=none, max_iter=400, l1_ratio=0.0, fit_intercept=True, C=0.5, total=   0.0s
# [CV] solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=l1, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5
# [CV]  solver=saga, penalty=elasticnet, max_iter=300, l1_ratio=1.0, fit_intercept=False, C=3.5, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=l1, max_iter=600, l1_ratio=0.8888888888888888, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5
# [CV]  solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5, total=   0.0s
# [CV] solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5
# [CV]  solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5, total=   0.0s
# [CV] solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5
# [CV]  solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5, total=   0.0s
# [CV] solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5
# [CV]  solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=none)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1505: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'False'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# [CV] solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5
# [CV]  solver=liblinear, penalty=l1, max_iter=100, l1_ratio=0.4444444444444444, fit_intercept=True, C=2.5, total=   0.0s
# [CV] solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0
# [CV]  solver=newton-cg, penalty=elasticnet, max_iter=500, l1_ratio=0.5555555555555556, fit_intercept=False, C=3.0, total=   0.0s
# [CV] solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0
# [CV]  solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0, total=   0.0s
# [CV] solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0
# [CV]  solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0, total=   0.0s
# [CV] solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0
# [CV]  solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0, total=   0.0s
# [CV] solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0
# [CV]  solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0, total=   0.0s
# [CV] solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0
# [CV]  solver=lbfgs, penalty=l2, max_iter=600, l1_ratio=0.5555555555555556, fit_intercept=True, C=2.0, total=   0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: invalid literal for int() with base 10: 'True'
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.1s finished
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='auto', n_jobs=None,
#                                                 penalty='l2', random_state=None,
#                                                 solver='lbfgs', tol=0.0001,
#                                                 verbose=0, warm_start=False),
#                    iid='deprecated', n_iter=10, n_jobs=1,
#                    param_distributions={'C': [0....
#                                                      0.3333333333333333,
#                                                      0.4444444444444444,
#                                                      0.5555555555555556,
#                                                      0.6666666666666666,
#                                                      0.7777777777777777,
#                                                      0.8888888888888888, 1.0],
#                                         'max_iter': [100, 200, 300, 400, 500,
#                                                      600],
#                                         'penalty': ['l1', 'l2', 'elasticnet',
#                                                     'none'],
#                                         'solver': ['newton-cg', 'lbfgs',
#                                                    'liblinear', 'sag',
#                                                    'saga']},
#                    pre_dispatch='2*n_jobs', random_state=100, refit=True,
#                    return_train_score=False, scoring=None, verbose=2)

# %%
lr_random.best_params_
# Out:
# {'solver': 'liblinear',
#  'penalty': 'l2',
#  'max_iter': 600,
#  'l1_ratio': 0.7777777777777777,
#  'fit_intercept': 'False',
#  'C': 3.0}

# %%
best_random_grid=lr_random.best_estimator_

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
y_pred=best_random_grid.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score{}".format((accuracy_score(y_test,y_pred))))
print("Classification report:{}".format(classification_report(y_test,y_pred)))
# Out:
# [[99  8]
#  [18 29]]
# Accuracy Score0.8311688311688312
# Classification report:              precision    recall  f1-score   support
#
#            0       0.85      0.93      0.88       107
#            1       0.78      0.62      0.69        47
#
#     accuracy                           0.83       154
#    macro avg       0.81      0.77      0.79       154
# weighted avg       0.83      0.83      0.82       154

# %%
lr_random.best_params_
# Out:
# {'solver': 'liblinear',
#  'penalty': 'l2',
#  'max_iter': 600,
#  'l1_ratio': 0.7777777777777777,
#  'fit_intercept': 'False',
#  'C': 3.0}

# %%
from sklearn.model_selection import GridSearchCV
param_grid={
    'max_iter':[lr_random.best_params_['max_iter']+70,lr_random.best_params_['max_iter']+30,lr_random.best_params_['max_iter']+50],
    'C':[lr_random.best_params_['C']+0.6,lr_random.best_params_['C']+0.3,lr_random.best_params_['C']+0.9],
    'fit_intercept':[lr_random.best_params_['fit_intercept']],
    'penalty':[lr_random.best_params_['penalty']],
    'solver':[lr_random.best_params_['solver']],
    'l1_ratio':[lr_random.best_params_['l1_ratio'],lr_random.best_params_['l1_ratio']+0.02,lr_random.best_params_['l1_ratio']-0.02]
}
print(param_grid)
# Out:
# {'max_iter': [670, 630, 650], 'C': [3.6, 3.3, 3.9], 'fit_intercept': ['False'], 'penalty': ['l2'], 'solver': ['liblinear'], 'l1_ratio': [0.7777777777777777, 0.7977777777777777, 0.7577777777777777]}

# %%
lr=LogisticRegression()
grid_search=GridSearchCV(estimator=lr,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(x_train,y_train.ravel())
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:    3.6s finished
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# GridSearchCV(cv=10, error_score=nan,
#              estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                           fit_intercept=True,
#                                           intercept_scaling=1, l1_ratio=None,
#                                           max_iter=100, multi_class='auto',
#                                           n_jobs=None, penalty='l2',
#                                           random_state=None, solver='lbfgs',
#                                           tol=0.0001, verbose=0,
#                                           warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'C': [3.6, 3.3, 3.9], 'fit_intercept': ['False'],
#                          'l1_ratio': [0.7777777777777777, 0.7977777777777777,
#                                       0.7577777777777777],
#                          'max_iter': [670, 630, 650], 'penalty': ['l2'],
#                          'solver': ['liblinear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
best_grid=grid_search.best_estimator_
best_grid
# Out:
# LogisticRegression(C=3.6, class_weight=None, dual=False, fit_intercept='False',
#                    intercept_scaling=1, l1_ratio=0.7777777777777777,
#                    max_iter=670, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
b_grid=lr_random.best_estimator_
b_grid
# Out:
# LogisticRegression(C=3.0, class_weight=None, dual=False, fit_intercept='False',
#                    intercept_scaling=1, l1_ratio=0.7777777777777777,
#                    max_iter=600, multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=best_grid.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score{}".format((accuracy_score(y_test,y_pred))))
print("Classification report:{}".format(classification_report(y_test,y_pred)))
# Out:
# [[99  8]
#  [18 29]]
# Accuracy Score0.8311688311688312
# Classification report:              precision    recall  f1-score   support
#
#            0       0.85      0.93      0.88       107
#            1       0.78      0.62      0.69        47
#
#     accuracy                           0.83       154
#    macro avg       0.81      0.77      0.79       154
# weighted avg       0.83      0.83      0.82       154

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = best_grid, X = x_train,y = y_train.ravel(), cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
accuracies
# Out:
# Accuracy: 76.05 %
# Standard Deviation: 4.94 %
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1501: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty))
# array([0.74193548, 0.74193548, 0.85483871, 0.77419355, 0.70491803,
#        0.7704918 , 0.75409836, 0.67213115, 0.81967213, 0.7704918 ])

# %% [markdown]
# comparing accuracy score with default classification  algorithms

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(x_train, y_train.ravel())
y_pred = classifier.predict(x_test)
print("Support vector machine(with kernal):{0}".format(accuracy_score(y_test,y_pred)))
# Out:
# Support vector machine(with kernal):0.7922077922077922

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train.ravel())
y_pred=classifier.predict(x_test)
print("KNN:{0}".format(accuracy_score(y_test,y_pred)))
# Out:
# KNN:0.7597402597402597

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train.ravel())
y_pred=classifier.predict(x_test)
print("Naive_bayes(Gaussian):{0}".format(accuracy_score(y_test,y_pred)))
# Out:
# Naive_bayes(Gaussian):0.7727272727272727

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train.ravel())
y_pred=classifier.predict(x_test)
print("RandomForest:{0}".format(accuracy_score(y_test,y_pred)))
# Out:
# RandomForest:0.7857142857142857

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = x_train,y = y_train.ravel(), cv = 5)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
accuracies
# Out:
# Accuracy: 72.97 %
# Standard Deviation: 3.04 %
# array([0.7398374 , 0.69918699, 0.77235772, 0.69105691, 0.74590164])

# %%
#hyperparameters for svc
C=[float(x)for x in np.linspace(0.5,4.0,9)]
kernel=['linear']
degree=[2,3,4]
#max_iter=[300,400]
coef=[0.5,1,1.5,2.5]
gamma=['scale', 'auto']
decision_function_shape=['ovo', 'ovr']

# %%
from sklearn.model_selection import GridSearchCV
grid_search={
    'C':C,
    'kernel':kernel,
    'degree':degree,
    'coef0':coef,
    'gamma':gamma,
    'decision_function_shape':decision_function_shape
}
print(grid_search)
# Out:
# {'C': [0.5, 0.9375, 1.375, 1.8125, 2.25, 2.6875, 3.125, 3.5625, 4.0], 'kernel': ['linear'], 'degree': [2, 3, 4], 'coef0': [0.5, 1, 1.5, 2.5], 'gamma': ['scale', 'auto'], 'decision_function_shape': ['ovo', 'ovr']}

# %%
svc.get_params().keys()

# %%
grid_search.best_params_
# Out:
# {'C': 0.5,
#  'coef0': 0.5,
#  'decision_function_shape': 'ovo',
#  'degree': 2,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': 400}

# %%
best=grid_search.best_estimator_

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0,decision_function_shape='ovo',gamma='scale',coef0=0.5,degree=2,C=3.5)
classifier.fit(x_train, y_train.ravel())
y_pred=classifier.predict(x_test)
print("Support vector machine(without kernal):{0}".format(accuracy_score(y_test,y_pred)))
# Out:
# Support vector machine(without kernal):0.8181818181818182

# %%
y_pred=best.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score{}".format((accuracy_score(y_test,y_pred))))
print("Classification report:{}".format(classification_report(y_test,y_pred)))
# Out:
# [[90 17]
#  [28 19]]
# Accuracy Score0.7077922077922078
# Classification report:              precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       107
#            1       0.53      0.40      0.46        47
#
#     accuracy                           0.71       154
#    macro avg       0.65      0.62      0.63       154
# weighted avg       0.69      0.71      0.70       154

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-1de756346af3> in <module>
#       3 X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       4                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
# ----> 5 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       6              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       7 plt.xlim(X1.min(), X1.max())
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     592             y = np.argmax(self.decision_function(X), axis=1)
#     593         else:
# --> 594             y = super().predict(X)
#     595         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     596
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     313         y_pred : array, shape (n_samples,)
#     314         """
# --> 315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
#     317         return predict(X)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _validate_for_predict(self, X)
#     465             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     466                              "the number of features at training time" %
# --> 467                              (n_features, self.shape_fit_[1]))
#     468         return X
#     469
#
# ValueError: X.shape[1] = 2 should be equal to 8, the number of features at training time
